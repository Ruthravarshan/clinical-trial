# %%
import pandas as pd

df = pd.read_pickle("my_dataframe.pkl")
display(df)
# Out:
#                                                    0   \
# 0                                      Trial Activity
# 1                                                Week
# 2                                              Day(s)
# 3                     Allowed window for visit (days)
# 4                                              Visits
# 5                                    Informed consent
# 6                        Inclusion/exclusion criteria
# 7                       Stable conventional treatment
# 8                  HIV,  HBV,  HCV,  EBV,  CMV \ntest
# 9                                             TB test
# 10                                      Randomisation
# 11                                       Demographics
# 12                         Alcohol and tobacco habits
# 13                       Medical and surgical history
# 14  UC \nmedical \nhistory, \nconfirmation  of  UC...
# 15       Urine \nscreening \nfor \ndrugs \nof \nabuse
# ...
